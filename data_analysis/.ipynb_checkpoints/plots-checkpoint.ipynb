# %% [markdown]
# # Setup

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
result_path = "/home/joel/resultsAsoc2021/outros_experimentos_testes/MOA1_noUpdateMtxMatrizByClassification/"

# %% [markdown]
# # Dataset Preparation

# %%
data_minasbr = pd.read_csv(result_path+"/MINAS-BR-Results.csv")
data_minasbr.head()
# Out:
#    Timestamp        F1        SA   HL        Pr        Re       F1m       F1M  \
# 0          1  0.962443  0.888453  0.0  0.960762  0.982623  0.963059  0.963584
# 1          2  0.964131  0.892947  0.0  0.956870  0.989182  0.964334  0.965875
# 2          3  0.962161  0.887615  0.0  0.954144  0.988818  0.963635  0.963510
# 3          4  0.959650  0.880102  0.0  0.950431  0.988773  0.962344  0.961054
# 4          5  0.956945  0.872688  0.0  0.946953  0.987991  0.960829  0.958424
#
#         Prm       PrM       Rem       ReM     unkRM  unk  removedUnk
# 0  0.949381  0.949952  0.977136  0.977612  0.005452   16           0
# 1  0.946469  0.946041  0.982886  0.986558  0.010259   25           0
# 2  0.943989  0.942049  0.984115  0.985970  0.014984   38          16
# 3  0.941108  0.937307  0.984559  0.986036  0.018195   40          30
# 4  0.938281  0.932953  0.984488  0.985324  0.022007   68          44

# %%
concept_evolution_window = pd.read_csv(os.path.join(result_path,"conceptEvolution-info.csv"))
concept_evolution_window
# Out:
#    Timestamp  window  label
# 0      30011      16      5
# 1      70005      38      6

# %%
np_windows = pd.read_csv(result_path+"NP-info.csv")
np_windows = np_windows.dropna().reset_index().drop(['index'],axis=1)
np_windows.columns = ["timestamp","NP","associated_class","timestamp_association","window_association"]
np_windows.head()
# Out:
#    timestamp   NP  associated_class  timestamp_association  window_association
# 0      31964  NP1               5.0                68400.0                37.0
# 1      31964  NP2               5.0                32400.0                17.0
# 2      31964  NP3               5.0                43200.0                23.0
# 3      31964  NP5               5.0                32400.0                17.0
# 4      31964  NP9               5.0                45000.0                24.0

# %%
x = np_windows['window_association'].duplicated().map(lambda i: not i)
np_windows_duplicated_less = np_windows[x]
np_windows_duplicated_less.reset_index(inplace=True)
np_windows_duplicated_less = np_windows_duplicated_less.drop(['index'],axis=1)
np_windows_duplicated_less = np_windows_duplicated_less.sort_values(by='window_association')
np_windows_duplicated_less
# Out:
#    timestamp    NP  associated_class  timestamp_association  \
# 1      31964   NP2               5.0                32400.0
# 4      31964  NP13               5.0                34200.0
# 6      31964  NP38               5.0                36000.0
# 2      31964   NP3               5.0                43200.0
# 3      31964   NP9               5.0                45000.0
# 0      31964   NP1               5.0                68400.0
# 5      31964  NP22               5.0                77400.0
# 7      81976  NP39               5.0                82800.0
# 8      81976  NP51               6.0                84600.0
#
#    window_association
# 1                17.0
# 4                18.0
# 6                19.0
# 2                23.0
# 3                24.0
# 0                37.0
# 5                42.0
# 7                45.0
# 8                46.0

# %% [markdown]
# # Plots

# %%
fig,axs = plt.subplots(2,gridspec_kw={
                           'width_ratios': [1],
                           'height_ratios': [1,7],
                            'hspace':0.05})
sns.lineplot(data=data_minasbr, y="F1M", x=data_minasbr.index, ax=axs[1])
sns.lineplot(data=data_minasbr,y="unkRM",x=data_minasbr.index,ax=axs[1])
axs[1].set_ylim(0,1)
axs[1].set_xlim(0,50)
axs[0].set_xlim(0,50)
axs[0].set_xticks([])
axs[0].set_yticks([])
fig.set_size_inches(12,6)

for i in concept_evolution_window.index:
#     axs[0].annotate(concept_evolution_window['label'].iloc[i],
#                 xy=(concept_evolution_window['window'].iloc[i]-1, 0), 
#                 xycoords='data',
#                 bbox=dict(boxstyle="round", fc="red", ec="red"),
#                 xytext=(15, 10),
#                 textcoords='offset points',
#                 ha='center',
#                 arrowprops=dict(arrowstyle="->"),
                fontsize=16)
    axs[0].vlines(x=concept_evolution_window['window']-1,
            ymin=0,
            ymax=1,
            colors='black',
            linestyles='solid')
# pos = [60,40,20,40,20,20,20,40,20]
for i in np_windows_duplicated_less.index:
    label = str(np_windows_duplicated_less['associated_class'].iloc[i])
#     ax.annotate(label, xy=(np_windows.iloc[i,-1]-1, 1),  xycoords='data',
#                 xytext=(0, pos[i]), textcoords='offset points', ha='center',
#                 arrowprops=dict(arrowstyle="->"),
#                 bbox=dict(boxstyle="round", fc="cyan", ec="white"),
#                 fontsize=12)

    axs[1].vlines(x=np_windows.iloc[i,-1]-1,
            ymin=0,
            ymax=1,
            colors='black',
            linestyles='dashed',
            label="NP1")

axs[1].set_xlabel("Windows", fontsize=18)
axs[1].set_ylabel("F1M and UnkRM", fontsize=18)
axs[1].tick_params(labelsize=12)
# plt.savefig("teste.pdf",dpi=300, format='pdf', bbox_inches='tight')
